# %% [markdown]
# # Spotify Playlist - Data Preprocessing

# %% [markdown]
# In this notebook, data is being preprocessed for ML method application. A challenge dataset containing 10000 Spotify playlists is used and cluttered playlists will be extracted from it, and then features will be retrieved for each track within a playlist. These features will be retrieved from the Spotify API based on track IDs and after retrieval, playlists will be saved to a json file, which will be used in a different notebook.
#
# *Note: A potentially cluttered playlists in this case is defined as any playlist with 50 or more tracks*

# %% [markdown]
# The first step is importing the necessary libraries and establishing credentials to connect to the Spotify API

# %%
import pandas as pd
import numpy as np 
import json
import spotipy
from spotipy import SpotifyClientCredentials, util
import time

client_id='your-client-id'
client_secret='your-client-secret'

#Credentials to access the Spotify Music Data
manager = SpotifyClientCredentials(client_id,client_secret)
sp = spotipy.Spotify(client_credentials_manager=manager)

# %% [markdown]
# The following part defines the necessary functions and demonstrates how each of them operates on a sample playlist

# %%
#Read json data and convert to DataFrame
def get_dataset():
    playlists_set = pd.read_json('challenge_set.json')
    return playlists_set
playlists_set = get_dataset()
playlists_set
# Out:
#                            date version  \
# 0    2018-01-16 08:47:28.198015      v1
# 1    2018-01-16 08:47:28.198015      v1
# 2    2018-01-16 08:47:28.198015      v1
# 3    2018-01-16 08:47:28.198015      v1
# 4    2018-01-16 08:47:28.198015      v1
# ...                         ...     ...
# 9995 2018-01-16 08:47:28.198015      v1
# 9996 2018-01-16 08:47:28.198015      v1
# 9997 2018-01-16 08:47:28.198015      v1
# 9998 2018-01-16 08:47:28.198015      v1
# 9999 2018-01-16 08:47:28.198015      v1
#
#                                               playlists  \
# 0     {'name': 'spanish playlist', 'num_holdouts': 1...
# 1     {'name': 'Groovin', 'num_holdouts': 48, 'pid':...
# 2     {'name': 'uplift', 'num_holdouts': 40, 'pid': ...
# 3     {'name': 'WUBZ', 'num_holdouts': 27, 'pid': 10...
# 4     {'name': 'new', 'num_holdouts': 41, 'pid': 100...
# ...                                                 ...
# 9995  {'name': 'Playlist 2015', 'num_holdouts': 20, ...
# 9996  {'name': 'Workout', 'num_holdouts': 24, 'pid':...
# 9997  {'name': 'Girlz', 'num_holdouts': 16, 'pid': 1...
# 9998  {'name': 'let's get lost', 'num_holdouts': 35,...
# 9999  {'name': 'Mama', 'num_holdouts': 28, 'pid': 10...
#
#                                     name  \
# 0     build/challenge/challenge_set.json
# 1     build/challenge/challenge_set.json
# 2     build/challenge/challenge_set.json
# 3     build/challenge/challenge_set.json
# 4     build/challenge/challenge_set.json
# ...                                  ...
# 9995  build/challenge/challenge_set.json
# 9996  build/challenge/challenge_set.json
# 9997  build/challenge/challenge_set.json
# 9998  build/challenge/challenge_set.json
# 9999  build/challenge/challenge_set.json
#
#                                           description
# 0     the challenge set for the RecSys Challenge 2018
# 1     the challenge set for the RecSys Challenge 2018
# 2     the challenge set for the RecSys Challenge 2018
# 3     the challenge set for the RecSys Challenge 2018
# 4     the challenge set for the RecSys Challenge 2018
# ...                                               ...
# 9995  the challenge set for the RecSys Challenge 2018
# 9996  the challenge set for the RecSys Challenge 2018
# 9997  the challenge set for the RecSys Challenge 2018
# 9998  the challenge set for the RecSys Challenge 2018
# 9999  the challenge set for the RecSys Challenge 2018
#
# [10000 rows x 5 columns]

# %%
#Extract a sample playlist
def get_playlist_from_dataset(playlists_set, index):
    playlists = playlists_set.playlists
    playlist = pd.DataFrame(playlists[index])
    return playlist
playlist = get_playlist_from_dataset(playlists_set, 8000)
playlist
# Out:
#        name  num_holdouts      pid  num_tracks  \
# 0   bangerz            57  1018569         157
# 1   bangerz            57  1018569         157
# 2   bangerz            57  1018569         157
# 3   bangerz            57  1018569         157
# 4   bangerz            57  1018569         157
# ..      ...           ...      ...         ...
# 95  bangerz            57  1018569         157
# 96  bangerz            57  1018569         157
# 97  bangerz            57  1018569         157
# 98  bangerz            57  1018569         157
# 99  bangerz            57  1018569         157
#
#                                                tracks  num_samples
# 0   {'pos': 1, 'artist_name': 'Kanye West', 'track...          100
# 1   {'pos': 2, 'artist_name': 'Young Thug', 'track...          100
# 2   {'pos': 3, 'artist_name': 'Kodak Black', 'trac...          100
# 3   {'pos': 4, 'artist_name': 'Kodak Black', 'trac...          100
# 4   {'pos': 6, 'artist_name': 'Kodak Black', 'trac...          100
# ..                                                ...          ...
# 95  {'pos': 149, 'artist_name': 'Meek Mill', 'trac...          100
# 96  {'pos': 150, 'artist_name': 'Meek Mill', 'trac...          100
# 97  {'pos': 151, 'artist_name': 'Meek Mill', 'trac...          100
# 98  {'pos': 154, 'artist_name': 'Meek Mill', 'trac...          100
# 99  {'pos': 155, 'artist_name': 'Meek Mill', 'trac...          100
#
# [100 rows x 6 columns]

# %%
#Preprocessing data - filtering only cluttered playlists
def filter_dataset(playlists_set):
    for i in range(0, len(playlists_set)):
        playlist = get_playlist_from_dataset(playlists_set, i)
        if (len(playlist.index) < 50):
            playlists_set.drop(labels=i, axis=0, inplace=True)
    length = len(playlists_set)
    result_set = playlists_set.reset_index(drop=True)
    return result_set, length
playlists_set, set_size = filter_dataset(playlists_set)
playlists_set
# Out:
#                            date version  \
# 0    2018-01-16 08:47:28.198015      v1
# 1    2018-01-16 08:47:28.198015      v1
# 2    2018-01-16 08:47:28.198015      v1
# 3    2018-01-16 08:47:28.198015      v1
# 4    2018-01-16 08:47:28.198015      v1
# ...                         ...     ...
# 1995 2018-01-16 08:47:28.198015      v1
# 1996 2018-01-16 08:47:28.198015      v1
# 1997 2018-01-16 08:47:28.198015      v1
# 1998 2018-01-16 08:47:28.198015      v1
# 1999 2018-01-16 08:47:28.198015      v1
#
#                                               playlists  \
# 0     {'name': 'April', 'num_holdouts': 63, 'pid': 1...
# 1     {'name': 'Other', 'num_holdouts': 73, 'pid': 1...
# 2     {'name': 'Classic', 'num_holdouts': 83, 'pid':...
# 3     {'name': '2016', 'num_holdouts': 61, 'pid': 10...
# 4     {'name': 'Party songs ', 'num_holdouts': 100, ...
# ...                                                 ...
# 1995  {'name': 'Indie', 'num_holdouts': 83, 'pid': 1...
# 1996  {'name': 'The Collection', 'num_holdouts': 96,...
# 1997  {'name': 'Main', 'num_holdouts': 111, 'pid': 1...
# 1998  {'name': '💃🏻', 'num_holdouts': 70, 'pid': 1049...
# 1999  {'name': 'Bean', 'num_holdouts': 69, 'pid': 10...
#
#                                     name  \
# 0     build/challenge/challenge_set.json
# 1     build/challenge/challenge_set.json
# 2     build/challenge/challenge_set.json
# 3     build/challenge/challenge_set.json
# 4     build/challenge/challenge_set.json
# ...                                  ...
# 1995  build/challenge/challenge_set.json
# 1996  build/challenge/challenge_set.json
# 1997  build/challenge/challenge_set.json
# 1998  build/challenge/challenge_set.json
# 1999  build/challenge/challenge_set.json
#
#                                           description
# 0     the challenge set for the RecSys Challenge 2018
# 1     the challenge set for the RecSys Challenge 2018
# 2     the challenge set for the RecSys Challenge 2018
# 3     the challenge set for the RecSys Challenge 2018
# 4     the challenge set for the RecSys Challenge 2018
# ...                                               ...
# 1995  the challenge set for the RecSys Challenge 2018
# 1996  the challenge set for the RecSys Challenge 2018
# 1997  the challenge set for the RecSys Challenge 2018
# 1998  the challenge set for the RecSys Challenge 2018
# 1999  the challenge set for the RecSys Challenge 2018
#
# [2000 rows x 5 columns]

# %%
#Obtain track IDs for each track in the playlist
def get_track_ids(playlist):
    track_uris = []
    for i in range(0, len(playlist)):
        track_uris.append(playlist['tracks'][i]['track_uri'])
    track_ids = []
    for uri in track_uris:
        track_ids.append(uri.split(':')[-1])
    return track_ids
track_ids = get_track_ids(playlist)
track_ids
# Out:
# ['1Wsbr1d2BouNGk2q92mIj7',
#  '20dP2DaMHIAmwWAbp7peSr',
#  '34oWbFBfGEElvgO0a5c9V4',
#  '5v7kaZNsnyByrSJOfO8gKq',
#  '32nztUVOEvvlUtKBufJuzq',
#  '6vFpwoagZKaQveINvGrbFK',
#  '4X5f3vT8MRuXF68pfjNte5',
#  '7odIekt1GqLVEAAWdnd9mJ',
#  '2KpCpk6HjXXLb7nnXoXA5O',
#  '2Kbxfq8wkjMCno1QJe4yyw',
#  '22DKsoYFV5npPXmnPpXL7i',
#  '6gBFPUFcJLzWGx4lenP6h2',
#  '1Ci4wASMY4xtKVMeHA6Sd5',
#  '0m1KYWlT6LhFRBDVq9UNx4',
#  '63OmVzNwoMNn6hT7p5vwvX',
#  '2AGUFka8kBWCM47h5uTlDb',
#  '177WEvlLsCc0FzCTWslawr',
#  '5mPSyjLatqB00IkPqRlbTE',
#  '0N3W5peJUQtI4eyR6GJT5O',
#  '42GcjriRK6srwHkfbkBqVl',
#  '2UOYzhusMTypF7oAQwksCj',
#  '5GhJq5J9ZWIEDZdyw7EWzt',
#  '26oF6WjkOjDIRK9YsdZp2l',
#  '6BbINUfGabVyiNFJpQXn3x',
#  '3NJG6vMH1ZsectZkocMEm0',
#  '2gZUPNdnz5Y45eiGxpHGSc',
#  '7lL3MvFWFFSD25pBz72Agj',
#  '1NMYfyq8eE4qUCj2SXvrJd',
#  '0pSBuHjILhNEo55xK1zrRt',
#  '3sgL7CN65BzZq3qqG9SkJZ',
#  '3AIgVHfr3FnXJvcdwgP7Km',
#  '2bjwRfXMk4uRgOD9IBYl9h',
#  '0xl1w2q4VLojeXp4JfazPL',
#  '7qqOmEfeTPgjBsm1Qm98eg',
#  '4XkOcWt0C2JX1s2RXybosk',
#  '0Fv5N0cHBsl4bzCbollCAS',
#  '5NQbUaeTEOGdD6hHcre0dZ',
#  '0bXFIF7iL17TYLyx8JHziM',
#  '1UGD3lW3tDmgZfAVDh6w7r',
#  '2h3i5tGUl6hMu572umjcGo',
#  '2EEeOnHehOozLq4aS0n6SL',
#  '0VgkVdmE4gld66l8iyGjgx',
#  '4w7yrP4RAeeyhfG9nJqQvS',
#  '4STaHtfguDMkWbPEo6Fwcx',
#  '5LQBxdLXL4Bk55XCP3Ksne',
#  '5YYjsDIxJKpVgNLkPpBmRA',
#  '5MUxrNd7Gr2HksLcAlB0IO',
#  '1KsfhDZbBY2JjTHLmYhkK1',
#  '0tISnxqgVmxqhVghsTi2Rr',
#  '1e1JKLEDKP7hEQzJfNAgPl',
#  '3hDp5jRxvtD31giFGUaE1x',
#  '16bHRxM89ue0TiCKARYbRp',
#  '7iaw359G2XT14uTfV9feip',
#  '5hx4FpDZOnDVYlyoG3rMks',
#  '1Xpj3QviqIEVqPS2YbivL3',
#  '3DC1b7nhk4pMi92CoLNOjc',
#  '41nFodiQgbNhVrPsLuKZ2a',
#  '204U3zjm9kkzX25Pr4Rdld',
#  '2eqUZAVXjK61mZqLl4LKJJ',
#  '5xkTHyhR9kCuFvqPkjgpId',
#  '1f5cbQtDrykjarZVrShaDI',
#  '2of5xn0GU0TdFneR1saRLH',
#  '7lxZbmtC6SkUc2yXBgDOdO',
#  '4vv1KjUzPwrtDbozizSfQc',
#  '2G60ShHRZZhqxSKbZTWdOh',
#  '5ndHl6BMrihdTqvT6Exhln',
#  '49rmaKoHG4RbmX4bWBy1mS',
#  '6riQuAkwS7qaOLkcCnyiJ4',
#  '2ClE3QfsNx9p0zjPKxmUYq',
#  '5zlSTZhZq6rXL4Xn2PBayO',
#  '39pS70eeDvyCAF3t8NAlVV',
#  '1nX9KhK3Fff27SnrIor2Yb',
#  '0NUv9KAJeJM6dndf1rXbU9',
#  '5tkDCf3xKRZjT5RbCb3sZB',
#  '0yyiXNPik06E8YOwWZoY8i',
#  '67gmXPQZL1ISSh13OJJ1Pu',
#  '1Qxj5nxpN2zXWYngetSiRi',
#  '25oOaleife6E2MIKmFkPvg',
#  '3YjQfsV7vIDj0eovuUlbK7',
#  '4cvUik0BhfRXJyEGtTYuut',
#  '5kpnUpMNV9dPNCKY7JtW3Q',
#  '5A0NEY8GOCB3ErRSRPpY72',
#  '5Je1fS7wNMhngKuU0fKUvw',
#  '26RcjBcThMrZ8KvsqApOvN',
#  '2wQVmS0j4xcSbEK8CLEgwz',
#  '7ncDwhSTgCZuL3OZNkvZ97',
#  '4fFZW98VLhdZSlyC07wt6v',
#  '4Ri31pnazSTnF439vC5tc3',
#  '5S3C2KkjFcu6J4G1lKAcMI',
#  '1CGP5ioAXECjvTJdMTvX0O',
#  '2IjgKCbrk8CtqmsOC5DhVd',
#  '6yMxfx9wpiuhhdb8vHDVMu',
#  '1GOuHB20lqVyxv3GdxovPY',
#  '7mlkO7fkD1tJrxoqOMGzqF',
#  '6TWgRy0WZEyPFIkYU505s8',
#  '7dK9JJXrbDFc29n23BqUso',
#  '2C4XQsZFeze4yMatFzY9M2',
#  '2N3LQk27fglVbVqQ8zA6lQ',
#  '6pVSAHKEKOWxDcfr8haIGe',
#  '7yGJcaSJgpgXamjmXBCb6j']

# %%
#Obtain track features based on a track ID
def get_track_features(id):

    meta = sp.track(id)
    features = sp.audio_features(id)

    # meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    release_date = meta['album']['release_date']
    length = meta['duration_ms']
    popularity = meta['popularity']
    ids =  meta['id']

    # features
    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    instrumentalness = features[0]['instrumentalness']
    liveness = features[0]['liveness']
    valence = features[0]['valence']
    loudness = features[0]['loudness']
    speechiness = features[0]['speechiness']
    tempo = features[0]['tempo']
    key = features[0]['key']
    time_signature = features[0]['time_signature']

    track = [name, album, artist, ids, release_date, popularity, length, danceability, acousticness,
            energy, instrumentalness, liveness, valence, loudness, speechiness, tempo, key, time_signature]
    columns = ['name','album','artist','id','release_date','popularity','length','danceability','acousticness','energy','instrumentalness',
                'liveness','valence','loudness','speechiness','tempo','key','time_signature']
    return track,columns
track, columns = get_track_features(track_ids[0])
track, columns
# Out:
# (['Pt. 2',
#   'The Life Of Pablo',
#   'Kanye West',
#   '1Wsbr1d2BouNGk2q92mIj7',
#   '2016-06-10',
#   68,
#   130293,
#   0.674,
#   0.552,
#   0.752,
#   0,
#   0.787,
#   0.236,
#   -4.073,
#   0.333,
#   145.076,
#   11,
#   4],
#  ['name',
#   'album',
#   'artist',
#   'id',
#   'release_date',
#   'popularity',
#   'length',
#   'danceability',
#   'acousticness',
#   'energy',
#   'instrumentalness',
#   'liveness',
#   'valence',
#   'loudness',
#   'speechiness',
#   'tempo',
#   'key',
#   'time_signature'])

# %%
#Create a DataFrame of all the playlist tracks and their respective features
def create_playlist_dataframe(track_ids):
    tracks = []
    for track_id in track_ids:
        time.sleep(.5)
        track, columns = get_track_features(track_id)
        tracks.append(track)
    df1 = pd.DataFrame(tracks,columns=columns)
    return df1
df1 = create_playlist_dataframe(track_ids)
df1
# Out:
#                                                  name  \
# 0                                               Pt. 2
# 1                                   pick up the phone
# 2                                         No Flockin'
# 3                                                Skrt
# 4                                   Vibin In This Bih
# ..                                                ...
# 95                                          Fall Thru
# 96                    Never Lose (feat. Lihtz Kamraz)
# 97                                            Glow Up
# 98                          Ball Player (feat. Quavo)
# 99  Made It from Nothing (feat. Teyana Taylor and ...
#
#                               album        artist                      id  \
# 0                 The Life Of Pablo    Kanye West  1Wsbr1d2BouNGk2q92mIj7
# 1   Birds In The Trap Sing McKnight  Travis Scott  20dP2DaMHIAmwWAbp7peSr
# 2                       No Flockin'   Kodak Black  34oWbFBfGEElvgO0a5c9V4
# 3                              Skrt   Kodak Black  5v7kaZNsnyByrSJOfO8gKq
# 4                       Lil Big Pac   Kodak Black  32nztUVOEvvlUtKBufJuzq
# ..                              ...           ...                     ...
# 95                    Wins & Losses     Meek Mill  7dK9JJXrbDFc29n23BqUso
# 96                    Wins & Losses     Meek Mill  2C4XQsZFeze4yMatFzY9M2
# 97                    Wins & Losses     Meek Mill  2N3LQk27fglVbVqQ8zA6lQ
# 98                    Wins & Losses     Meek Mill  6pVSAHKEKOWxDcfr8haIGe
# 99                    Wins & Losses     Meek Mill  7yGJcaSJgpgXamjmXBCb6j
#
#    release_date  popularity  length  danceability  acousticness  energy  \
# 0    2016-06-10          68  130293         0.674        0.5520   0.752
# 1    2016-09-16          70  252256         0.711        0.1140   0.739
# 2    2015-11-13          72  165290         0.943        0.0673   0.595
# 3    2016-02-12          62  224864         0.901        0.5850   0.352
# 4    2016-06-10           0  169926         0.710        0.0171   0.579
# ..          ...         ...     ...           ...           ...     ...
# 95   2017-07-21          47  222780         0.558        0.3840   0.808
# 96   2017-07-21          34  236520         0.759        0.0306   0.792
# 97   2017-07-21          44  210346         0.720        0.0823   0.783
# 98   2017-07-21          40  251706         0.724        0.0457   0.827
# 99   2017-07-21          35  249613         0.395        0.2710   0.640
#
#     instrumentalness  liveness  valence  loudness  speechiness    tempo  key  \
# 0                0.0    0.7870    0.236    -4.073       0.3330  145.076   11
# 1                0.0    0.2260    0.430    -3.804       0.1290  136.919    7
# 2                0.0    0.0839    0.815    -8.372       0.1910  117.532    5
# 3                0.0    0.1220    0.199   -10.038       0.0916  111.065    2
# 4                0.0    0.1050    0.305    -5.724       0.2120  163.992    1
# ..               ...       ...      ...       ...          ...      ...  ...
# 95               0.0    0.2600    0.630    -4.284       0.3670  157.418    9
# 96               0.0    0.1420    0.542    -3.259       0.1770  130.119    1
# 97               0.0    0.1210    0.604    -4.097       0.1290   76.085    1
# 98               0.0    0.0848    0.200    -4.211       0.1290  144.973   11
# 99               0.0    0.1120    0.383    -3.678       0.0792  174.228    5
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %%
#Extract only necessary features from the df
def extract_features(df1):
    df = df1[['name','album','artist','id','release_date','popularity','danceability','energy','valence','loudness']]
    return df
df = extract_features(df1)
df
# Out:
#                                                  name  \
# 0                                               Pt. 2
# 1                                   pick up the phone
# 2                                         No Flockin'
# 3                                                Skrt
# 4                                   Vibin In This Bih
# ..                                                ...
# 95                                          Fall Thru
# 96                    Never Lose (feat. Lihtz Kamraz)
# 97                                            Glow Up
# 98                          Ball Player (feat. Quavo)
# 99  Made It from Nothing (feat. Teyana Taylor and ...
#
#                               album        artist                      id  \
# 0                 The Life Of Pablo    Kanye West  1Wsbr1d2BouNGk2q92mIj7
# 1   Birds In The Trap Sing McKnight  Travis Scott  20dP2DaMHIAmwWAbp7peSr
# 2                       No Flockin'   Kodak Black  34oWbFBfGEElvgO0a5c9V4
# 3                              Skrt   Kodak Black  5v7kaZNsnyByrSJOfO8gKq
# 4                       Lil Big Pac   Kodak Black  32nztUVOEvvlUtKBufJuzq
# ..                              ...           ...                     ...
# 95                    Wins & Losses     Meek Mill  7dK9JJXrbDFc29n23BqUso
# 96                    Wins & Losses     Meek Mill  2C4XQsZFeze4yMatFzY9M2
# 97                    Wins & Losses     Meek Mill  2N3LQk27fglVbVqQ8zA6lQ
# 98                    Wins & Losses     Meek Mill  6pVSAHKEKOWxDcfr8haIGe
# 99                    Wins & Losses     Meek Mill  7yGJcaSJgpgXamjmXBCb6j
#
#    release_date  popularity  danceability  energy  valence  loudness
# 0    2016-06-10          68         0.674   0.752    0.236    -4.073
# 1    2016-09-16          70         0.711   0.739    0.430    -3.804
# 2    2015-11-13          72         0.943   0.595    0.815    -8.372
# 3    2016-02-12          62         0.901   0.352    0.199   -10.038
# 4    2016-06-10           0         0.710   0.579    0.305    -5.724
# ..          ...         ...           ...     ...      ...       ...
# 95   2017-07-21          47         0.558   0.808    0.630    -4.284
# 96   2017-07-21          34         0.759   0.792    0.542    -3.259
# 97   2017-07-21          44         0.720   0.783    0.604    -4.097
# 98   2017-07-21          40         0.724   0.827    0.200    -4.211
# 99   2017-07-21          35         0.395   0.640    0.383    -3.678
#
# [100 rows x 10 columns]

# %% [markdown]
# Now that we have demonstrated (on a sample playlist) how data is retrieved, filtered and processed, the same process will be repeated for other playlists from the dataset and they will be saved in a new json file, ready for applying algorithms.

# %%
#Write playlist to a JSON file
def write_json(new_data, filename='playlists.json'):
    with open(filename,'r+') as file:
        # load existing data into a dict
        file_data = json.load(file)
        # join new_data with file_data 
        file_data["playlists"].append(new_data)
        file_data["size"] = file_data["size"] + 1
        # set file's current position at offset
        file.seek(0)
        # convert back to json
        json.dump(file_data, file, indent = 2)

# %%
#Apply entire procedure to 200 playlists from the dataset
for i in range(0, 200):
    playlist = get_playlist_from_dataset(playlists_set, i)
    track_ids = get_track_ids(playlist)
    df1 = create_playlist_dataframe(track_ids)
    df = extract_features(df1)
    jsonDF = json.loads(df.to_json(orient="columns"))
    write_json(jsonDF)
